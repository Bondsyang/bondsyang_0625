# %%
import random

play_count = 0 #route區，一定會執行

while(True):

    min = 1
    max = 100
    count = 0
    guess_value = random.randint(min,max)  #前面一定要比後面小
    # print(guess_value)
    
    print("==========猜數字遊戲===========\n")
    while(True):
        count += 1
        try:
            keyin = int(input(f"猜數字範圍{min}~{max}"))
                        
            if not (min <= keyin <= max):
                raise Exception(f"輸入範圍請在{min}~{max}")
            else:
                if(keyin ==  guess_value):   #連在一起加()；嚴格的放最前面
                    print(f"賓果!猜對了，答案是:{guess_value}")
                    print(f"您猜了{count}次")
                    break

                elif keyin > guess_value:
                    print("再小一點")
                    max = keyin - 1
                
                else:
                    print("再大一點")
                    min = keyin + 1
        
        except ValueError as e:
            print("格式錯誤",e)
        
        except Exception as e:
            print(e)
        
        
        print(f"您已經猜{count}次")
      
    play_count += 1
    retry = input("請問是否還要繼續嗎？(y,n)")
        
    if retry == "y":
        continue
    else:
        print(f"遊戲結束，感謝您遊玩此遊戲{play_count}次")
    break
# Out:
# 81
# ==========猜數字遊戲===========
#
# 再大一點
# 您已經猜1次
# 賓果!猜對了，答案是:81
# 您猜了2次
# 24
# ==========猜數字遊戲===========
#
# 賓果!猜對了，答案是:24
# 您猜了1次
# 遊戲結束，感謝您遊玩此遊戲2次

# %%
#老師的寫法

import random

play_count = 0

while(True):
    play_count += 1
    min = 1
    max = 100
    count = 0
    guess_value = random.randint(min,max)
    # print(guess_value)
    print("==========猜數字遊戲===========\n")
    while(True):
        try:
            count += 1
            keyin = int(input(f"猜數字範圍{min}~{max}"))        
            if keyin >= min and keyin <= max:
                if(keyin == guess_value):
                    print(f"賓果!猜對了,答案是:{guess_value}")
                    print(f"您猜了{count}次")
                    break
                elif keyin > guess_value:
                    print("再小一點!")
                    max = keyin - 1
                
                else:
                    print("再大一點")
                    min = keyin + 1

                print(f"您已經猜{count}次")
                
            else:
                print("請輸入提示範圍內的數字")
        except ValueError:
            print("格式錯誤")
        except Exception as e:
            print(e)
    is_continue = input("您還要繼續嗎(y,n)?")
    if is_continue == "n":
        break

print(f"您共玩了{play_count}次")
print("遊戲結束")
# Out:
# 94
# ==========猜數字遊戲===========
#
# 再大一點
# 您已經猜1次
# 格式錯誤
# 再大一點
# 您已經猜3次
# 賓果!猜對了,答案是:94
# 您猜了4次
# 21
# ==========猜數字遊戲===========
#
# 再小一點!
# 您已經猜1次
# 賓果!猜對了,答案是:21
# 您猜了2次
# 您共玩了2次
# 遊戲結束
