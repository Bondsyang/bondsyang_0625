# %%
#1家分店30天的營收
import numpy as np
one_store = np.random.randint(100, 10000, size=(30, ))
one_store
# Out:
# array([2484, 8307, 7127, 9467, 1459, 2518, 1214, 7221, 3142, 1994, 2804,
#         434, 3449, 7534, 2173, 9032, 1532, 2245,  179,  487, 5947,  533,
#        4798,  381,  691, 6523, 9088, 6216, 6332,  966], dtype=int32)

# %%
#累計每天這家店的營收
oneStoreCum = np.cumsum(one_store)
oneStoreCum
# Out:
# array([  2484,  10791,  17918,  27385,  28844,  31362,  32576,  39797,
#         42939,  44933,  47737,  48171,  51620,  59154,  61327,  70359,
#         71891,  74136,  74315,  74802,  80749,  81282,  86080,  86461,
#         87152,  93675, 102763, 108979, 115311, 116277])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
