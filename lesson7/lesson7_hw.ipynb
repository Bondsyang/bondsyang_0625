# %%
import random

#play_count = 1

#while(True):
    #if play_count = 1 or :
    

min = 1
max = 100
count = 0
guess_value = random.randint(min,max)  #前面一定要比後面小
print("==========猜數字遊戲===========\n")
while(True):
    try:
        keyin = int(input(f"猜數字範圍{min}~{max}"))
        #count += 1
        if not (min <= keyin <= max):
            raise Exception(f"輸入範圍請在{min}~{max}")
        elif keyin >= min and keyin <= max:
            if(keyin ==  guess_value):   #連在一起加()；嚴格的放有最前面
                print(f"賓果!猜對了，答案是:{guess_value}")
                print(f"您猜了{count}次")
                break
            elif keyin > guess_value:
                print("再小一點")
                max = keyin - 1
            
            else:
                print("再大一點")
                min = keyin + 1

            #print(f"您已經猜{count}次")
            
        #else:
            #print("請輸入提示範圍內的數字")
    
    except ValueError as e:
        print("格式錯誤",e)
    except Exception as e:
        print(e)
    count += 1
    print(f"您已經猜{count}次")

print("遊戲結束")
# Out:
# ==========猜數字遊戲===========
#
# 格式錯誤 invalid literal for int() with base 10: '100a'
# 您已經猜1次
# 輸入範圍請在1~100
# 您已經猜2次
# 再大一點
# 您已經猜3次
# 再小一點
# 您已經猜4次
# 再小一點
# 您已經猜5次
# 再大一點
# 您已經猜6次
# 賓果!猜對了，答案是:35
# 您猜了6次
# 遊戲結束

# %%
import random

play_count = 0

while(True):

    min = 1
    max = 100
    count = 0
    guess_value = random.randint(min,max)  #前面一定要比後面小
    print("==========猜數字遊戲===========\n")
    while(True):
        try:
            keyin = int(input(f"猜數字範圍{min}~{max}"))
            #count += 1
            if not (min <= keyin <= max):
                raise Exception(f"輸入範圍請在{min}~{max}")
            elif keyin >= min and keyin <= max:
                if(keyin ==  guess_value):   #連在一起加()；嚴格的放有最前面
                    print(f"賓果!猜對了，答案是:{guess_value}")
                    count += 1
                    print(f"您猜了{count}次")
                    break

                elif keyin > guess_value:
                    print("再小一點")
                    max = keyin - 1
                
                else:
                    print("再大一點")
                    min = keyin + 1
        
        except ValueError as e:
            print("格式錯誤",e)
        
        except Exception as e:
            print(e)
        
        count += 1
        print(f"您已經猜{count}次")
      
    play_count += 1
    retry = input("請問是否還要繼續嗎？(y,n)")
        
    if retry == "y":
        continue
    else:
        print(f"遊戲結束，感謝您遊玩此遊戲{play_count}次")
    break
# Out:
# ==========猜數字遊戲===========
#
# 再小一點
# 您已經猜1次
# 格式錯誤 invalid literal for int() with base 10: '50a'
# 您已經猜2次
# 輸入範圍請在1~49
# 您已經猜3次
# 再大一點
# 您已經猜4次
# 再大一點
# 您已經猜5次
# 再大一點
# 您已經猜6次
# 再大一點
# 您已經猜7次
# 賓果!猜對了，答案是:48
# 您猜了8次
# ==========猜數字遊戲===========
#
# 再大一點
# 您已經猜1次
# 再大一點
# 您已經猜2次
# 再小一點
# 您已經猜3次
# 再小一點
# 您已經猜4次
# 再大一點
# 您已經猜5次
# 賓果!猜對了，答案是:58
# 您猜了6次
# 遊戲結束，感謝您遊玩此遊戲2次
